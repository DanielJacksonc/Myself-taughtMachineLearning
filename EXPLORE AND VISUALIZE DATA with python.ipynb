# %%
import pandas #WE want to import a module called pandas that will help us readour CSV.
from pandas import DataFrame #The Dataframe from pandas will help us split our Data into columns
import matplotlib.pyplot as plt # this plt is an alias to reduce long typing of matplotlib.pyplot

# %%
data =pandas.read_csv('cost_revenue_clean.csv') #We assign our raw data a name "data" to be our place holder.

# %%
data.describe() # this function shows us the important information about our data.
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X = DataFrame(data, columns =['production_budget_usd'])
y = DataFrame (data, columns =['worldwide_gross_usd'])

# %% [markdown]
# ##### 3 .after the step above, we would want to visualize our data using 'MATPLOITLAB'

# %%
#This model will help us create our charts. for this work, we only need a portion called Pyplot for this, so we import it.

# %%
#Graph 1 
#####matplotlib.pyplot.scatter(X, y)  #this plots are scattered plot for us.
#####matplotlib.pyplot.show()           #this shows the plotted graph

#lets enjoy. From the code above you can see how long it it, we can shorten it by introducing alias knowm as PLT .

#something like
plt.figure(figsize=(10,6) ) 
plt.scatter(X, y)
plt.title('Film cost vs Global Revenue')
plt.xlabel('Production budget $')
plt.ylabel('Worldwide Gross $')
plt.show()

# %%
#grapgh 2

plt.figure(figsize=(10,6) ) 
plt.scatter(X, y, alpha=0.3)
plt.title('Film cost vs Global Revenue')
plt.xlabel('Production budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %% [markdown]
# ### DOCUMENTATION OF MY PROCESS

# %% [markdown]
# 1. WE started by importing pandas which wouold allow us read through a CSV file for file interpretation.
# 2. I uploaded my csv fil.
# 3. I used my describe function to see the details of my data.
# 4. I assigned a name to the data. something like (data = pandas.read_csv("the file name")✔
# 5. I called a DataFrame on the pandas to help me split the data into frames.
# 6. I splitted my data into X and y. this will help me to plot graphs (X = dataFrame(data, columns ("the column name") same for y
# 7. I imported the matplotlib library for visualization. and also called a small portion called pyplot.
# 8. I plot the graph with scattered plot by typing matplotlib.pyplot.scatter(X, y)
# 9. I show the plot by typing matplotlib.pyplot.show()
# 10. the matploitlib.pyplot.scatter is long, so i alias the name with plt on the import module section.
# 11. i substitute the matploitlib.pyplot.with plt.scatter()
# 12. I introduce titles, labels and axis to the grapgh by adding the names to plt. (plt.title(X,y) or .xlabel("mmmm") or .ylabel(
# 13. i will make the graph bigger by using .figure(figsize=(10,6) where 10 is width and 6 is height.
# 14. I remove the splace below 0.0 and 0 in grapgh  1 to make grapgh 2. Set a range (plt.ylim(0, 3000000000))
# 15. repeat 14 for the x axis.
# 16. to determine areas that are dense, lets add transparency to our plot. I will add  apha=0.3 to my plt.scatter
#
# #### EXPLAINATION OF OUR GRAPGH
#
# WE can see the datapoint in our chats. at this point we can see the most clear outliers. e.g like the data at the most right(avatar). what is very clear here is that we can see the relationship between mpvie bufget s and revenue.
# we need to find the relationship between this variable. we will need LINEAR REGRESSION.
#
# #### SEE YOU IN THE NEXT LINE./❤❤✔✌✌✌
